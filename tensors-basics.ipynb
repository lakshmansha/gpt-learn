# %% [markdown]
# # Introduction to PyTorch Tensors for LLMs
#
# This notebook walks through the basics of PyTorch tensors and operations that are building blocks for Large Language Models (LLMs).

# %%
import torch

# %% [markdown]
# ## 1. Tensor Creation
# ##### Create Tensor datatype
#
# ![image.png](attachment:image.png)

# %%
# Create Tensor Datatype

# %% [markdown]
# ## 2. Ones
#
# ![image.png](attachment:image.png)

# %%
# create all ones for the 2, 3 tensor

# %% [markdown]
# ## 3. Random
#
# ![image.png](attachment:image.png)

# %%
# randomize 2, 3 tensor

# %% [markdown]
# ## 4. Shape
#
# ![image.png](attachment:image.png)

# %%
# check the shape of x and rand

# %% [markdown]
# ## 5. Reshape
# ![image.png](attachment:image.png)

# %%
# Reshape the random tensor

# %% [markdown]
# ## 6. Transpose
# ![image.png](attachment:image.png)

# %%
# Transpose the rand

# %% [markdown]
# ## 7. Linear Layer
# ![image.png](attachment:image.png)

# %%
# Apply a linear transformation for tensor

# %% [markdown]
# ## 8. Embedding
#
# ![image.png](attachment:image.png)

# %%
# Simple vocab of words
vocab = {"hello": 0, "world": 1, "llm": 2, "tensor": 3, "pytorch": 4}

# Create an embedding layer: vocab_size=5, embedding_dim=4
embedding = torch.nn.Embedding(len(vocab), 4)

# Example sentence: "hello world pytorch"
sentence = ["hello", "world", "pytorch"]

# Convert words to IDs

# Get embeddings

# %% [markdown]
# ## 9. Dot Product
#
# ![image.png](attachment:image.png)

# %%
# Compute dot product for emb[0] and emb[1]

# %% [markdown]
# ## 10. Batch Matrix Multiply (bmm)
# ![image.png](attachment:image.png)

# %%
#Multiply two tensors
a = torch.rand(2, 3, 4)
b = torch.rand(2, 4, 5)

# %% [markdown]
# ## 11. Triu (Upper Triangular Mask)
# ![image.png](attachment:image.png)

# %%
# create a right triangular upper mask

# %% [markdown]
# ## 12. Masked Fill
# ![image.png](attachment:image.png)

# %%
# fill the upper triangular part of the tensor with a -inf

# %% [markdown]
# ## 13. Softmax
#
# ![image.png](attachment:image.png)

# %%
# Normalize the masked scores with softmax

# %%
scaled = scores / torch.sqrt(torch.tensor(4.0))
print(scaled)

# %% [markdown]
# ## 14. LayerNorm
# ![image.png](attachment:image.png)

# %%
# Normalize emb from 8th step with 5
